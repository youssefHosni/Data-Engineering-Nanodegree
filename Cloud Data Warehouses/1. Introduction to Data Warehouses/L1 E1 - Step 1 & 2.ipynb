# %% [markdown]
# # Exercise 1 -  Sakila Star Schema & ETL
#
# All the database tables in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)

# %% [markdown]
# # STEP0: Using ipython-sql
#
# - Load ipython-sql: `%load_ext sql`
#
# - To execute SQL queries you write one of the following atop of your cell:
#     - `%sql`
#         - For a one-liner SQL query
#         - You can access a python var using `$`
#     - `%%sql`
#         - For a multi-line SQL query
#         - You can **NOT** access a python var using `$`
#
#
# - Running a connection string like:
# `postgresql://postgres:postgres@db:5432/pagila` connects to the database

# %% [markdown]
# # STEP1 : Connect to the local database where Pagila is loaded

# %% [markdown]
# ##  1.1 Create the pagila db and fill it with data
# - Adding `"!"` at the beginning of a jupyter cell runs a command in a shell, i.e. we are not running python code but we are running the `createdb` and `psql` postgresql commmand-line utilities

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ## 1.2 Connect to the newly created db

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila

# %%
# %sql $conn_string
# Out:
# 'Connected: student@pagila'

# %% [markdown]
# # STEP2 : Explore the  3NF Schema

# %% [markdown]
# <img src="./pagila-3nf.png" width="50%"/>

# %% [markdown]
# ## 2.1 How much? What data sizes are we looking at?

# %%
nStores = %sql select count(*) from store;
nFilms = %sql select count(*) from film;
nCustomers = %sql select count(*) from customer;
nRentals = %sql select count(*) from rental;
nPayment = %sql select count(*) from payment;
nStaff = %sql select count(*) from staff;
nCity = %sql select count(*) from city;
nCountry = %sql select count(*) from country;

print("nFilms\t\t=", nFilms[0][0])
print("nCustomers\t=", nCustomers[0][0])
print("nRentals\t=", nRentals[0][0])
print("nPayment\t=", nPayment[0][0])
print("nStaff\t\t=", nStaff[0][0])
print("nStores\t\t=", nStores[0][0])
print("nCities\t\t=", nCity[0][0])
print("nCountry\t\t=", nCountry[0][0])
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# nFilms		= 1000
# nCustomers	= 599
# nRentals	= 16044
# nPayment	= 16049
# nStaff		= 2
# nStores		= 2
# nCities		= 600
# nCountry		= 109

# %% [markdown]
# ## 2.2 When? What time period are we talking about?

# %%
# %%sql
# select min(payment_date) as start, max(payment_date) as end from payment;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# [(datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), datetime.datetime(2017, 5, 14, 13, 44, 29, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ## 2.3 Where? Where do events in this database occur?
# TODO: Write a query that displays the number of addresses by district in the address table. Limit the table to the top 10 districts. Your results should match the table below.

# %%
# %%sql
# select *
# from address;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 603 rows affected.
# [(1, '47 MySakila Drive', None, 'Alberta', 300, '', '', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (2, '28 MySQL Boulevard', None, 'QLD', 576, '', '', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, '23 Workhaven Lane', None, 'Alberta', 300, '', '14033335568', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (4, '1411 Lillydale Drive', None, 'QLD', 576, '', '6172235589', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (5, '1913 Hanoi Way', '', 'Nagasaki', 463, '35200', '28303384290', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (6, '1121 Loja Avenue', '', 'California', 449, '17886', '838635286649', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (7, '692 Joliet Street', '', 'Attika', 38, '83579', '448477190408', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (8, '1566 Inegl Manor', '', 'Mandalay', 349, '53561', '705814003527', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (9, '53 Idfu Parkway', '', 'Nantou', 361, '42399', '10655648674', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (10, '1795 Santiago de Compostela Way', '', 'Texas', 295, '18743', '860452626434', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (11, '900 Santiago de Compostela Parkway', '', 'Central Serbia', 280, '93896', '716571220373', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (12, '478 Joliet Way', '', 'Hamilton', 200, '77948', '657282285970', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (13, '613 Korolev Drive', '', 'Masqat', 329, '45844', '380657522649', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (14, '1531 Sal Drive', '', 'Esfahan', 162, '53628', '648856936185', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (15, '1542 Tarlac Parkway', '', 'Kanagawa', 440, '1027', '635297277345', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16, '808 Bhopal Manor', '', 'Haryana', 582, '10672', '465887807014', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (17, '270 Amroha Parkway', '', 'Osmaniye', 384, '29610', '695479687538', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (18, '770 Bydgoszcz Avenue', '', 'California', 120, '16266', '517338314235', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (19, '419 Iligan Lane', '', 'Madhya Pradesh', 76, '72878', '990911107354', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (20, '360 Toulouse Parkway', '', 'England', 495, '54308', '949312333307', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (21, '270 Toulon Boulevard', '', 'Kalmykia', 156, '81766', '407752414682', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (22, '320 Brest Avenue', '', 'Kaduna', 252, '43331', '747791594069', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (23, '1417 Lancaster Avenue', '', 'Northern Cape', 267, '72192', '272572357893', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (24, '1688 Okara Way', '', 'Nothwest Border Prov', 327, '21954', '144453869132', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (25, '262 A Corua (La Corua) Parkway', '', 'Dhaka', 525, '34418', '892775750063', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (26, '28 Charlotte Amalie Street', '', 'Rabat-Sal-Zammour-Z', 443, '37551', '161968374323', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  
datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (586, '951 Springs Lane', '', 'Central Mindanao', 219, '96115', '165164761435', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (587, '760 Miyakonojo Drive', '', 'Guerrero', 246, '64682', '294449058179', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (588, '966 Asuncin Way', '', 'Hidalgo', 212, '62703', '995527378381', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (589, '1584 Ljubertsy Lane', '', 'England', 494, '22954', '285710089439', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (590, '247 Jining Parkway', '', 'Banjul', 54, '53446', '170115379190', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (591, '773 Dallas Manor', '', 'Buenos Aires', 424, '12664', '914466027044', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (592, '1923 Stara Zagora Lane', '', 'Nantou', 546, '95179', '182178609211', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (593, '1402 Zanzibar Boulevard', '', 'Guanajuato', 106, '71102', '387448063440', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (594, '1464 Kursk Parkway', '', 'Shandong', 574, '17381', '338758048786', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (595, '1074 Sanaa Parkway', '', 'Loja', 311, '22474', '154124128457', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (596, '1759 Niznekamsk Avenue', '', 'al-Manama', 14, '39414', '864392582257', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (597, '32 Liaocheng Way', '', 'Minas Gerais', 248, '1944', '410877354933', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (598, '42 Fontana Avenue', '', 'Fejr', 512, '14684', '437829801725', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (599, '1895 Zhezqazghan Drive', '', 'California', 177, '36693', '137809746111', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (600, '1837 Kaduna Parkway', '', 'Inner Mongolia', 241, '82580', '640843562301', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (601, '844 Bucuresti Place', '', 'Liaoning', 242, '36603', '935952366111', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (602, '1101 Bucuresti Boulevard', '', 'West Greece', 401, '97661', '199514580428', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (603, '1103 Quilmes Boulevard', '', 'Piura', 503, '52137', '644021380889', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (604, '1331 Usak Boulevard', '', 'Vaud', 296, '61960', '145308717464', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (605, '1325 Fukuyama Street', '', 'Heilongjiang', 537, '27107', '288241215394', datetime.datetime(2017, 2, 15, 9, 45, 30, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %%
# %%sql
# select district,  count(district) as n
# from address
# group by district
# order by n desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Buenos Aires', 10),
#  ('California', 9),
#  ('Shandong', 9),
#  ('West Bengali', 9),
#  ('So Paulo', 8),
#  ('Uttar Pradesh', 8),
#  ('Maharashtra', 7),
#  ('England', 7),
#  ('Southern Tagalog', 6),
#  ('Punjab', 5)]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>district</th>
#         <th>n</th>
#     </tr>
#     <tr>
#         <td>Buenos Aires</td>
#         <td>10</td>
#     </tr>
#     <tr>
#         <td>California</td>
#         <td>9</td>
#     </tr>
#     <tr>
#         <td>Shandong</td>
#         <td>9</td>
#     </tr>
#     <tr>
#         <td>West Bengali</td>
#         <td>9</td>
#     </tr>
#     <tr>
#         <td>So Paulo</td>
#         <td>8</td>
#     </tr>
#     <tr>
#         <td>Uttar Pradesh</td>
#         <td>8</td>
#     </tr>
#     <tr>
#         <td>Maharashtra</td>
#         <td>7</td>
#     </tr>
#     <tr>
#         <td>England</td>
#         <td>7</td>
#     </tr>
#     <tr>
#         <td>Southern Tagalog</td>
#         <td>6</td>
#     </tr>
#     <tr>
#         <td>Punjab</td>
#         <td>5</td>
#     </tr>
# </tbody></table></div>
